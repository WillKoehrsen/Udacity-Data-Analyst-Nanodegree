# %%
import pandas as pd
import csv

# %%
df = pd.DataFrame.from_csv('sample_emissions.csv', header=0)

# %%
world_df = df[df.index == 'World']

# %%
world_df
# Out:
#          Year  Emissions
# Country
# World    2008   30835.18
# World    2009   30510.22
# World    2010   32313.03
# World    2011   33397.61
# World    2012   33730.18
# World    2013   34389.60

# %%
world_df.to_csv('world_emissions.csv')

# %%
df.drop('World', axis=0, inplace=True)

# %%
df
# Out:
#                       Year  Emissions
# Country
# Afghanistan           2008       4.21
# Albania               2008       4.17
# Algeria               2008     105.91
# Angola                2008      25.28
# Antigua & Barbuda     2008       0.48
# Argentina             2008     183.07
# Armenia               2008       5.65
# Australia             2008     394.96
# Austria               2008      72.28
# Azerbaijan            2008      29.60
# Bahamas, The          2008       1.49
# Bahrain               2008      24.83
# Bangladesh            2008      45.85
# Barbados              2008       1.62
# Belarus               2008      60.54
# Belgium               2008     107.11
# Belize                2008       0.38
# Benin                 2008       4.50
# Bhutan                2008       0.42
# Bolivia               2008      13.00
# Bosnia & Herzegovina  2008      20.94
# Botswana              2008       4.39
# Brazil                2008     377.74
# ...

# %%
df.describe()
# Out:
#               Year     Emissions
# count  1122.000000   1122.000000
# mean   2010.500000    201.095143
# std       1.708587    842.245768
# min    2008.000000      0.010000
# 25%    2009.000000      2.240000
# 50%    2010.500000     11.855000
# 75%    2012.000000     70.010000
# max    2013.000000  10183.730000

# %%
df.to_csv('country_emissions.csv')
